# %% [markdown]
# <a href="https://colab.research.google.com/github/Howl06/practice/blob/main/mv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pip install comet_ml
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 476.9/476.9 KB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 KB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 KB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 68.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 24.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 505.9/505.9 KB 52.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.5.1
#     Uninstalling websocket-client-1.5.1:
#       Successfully uninstalled websocket-client-1.5.1
# ...

# %%
# 分割驗證訓練
# !python /content/drive/MyDrive/model/deep-learning-for-image-processing-master/data_set/split_data.py

# %%
# !python /content/drive/MyDrive/model/deep-learning-for-image-processing-master/pytorch_classification/Test6_mobilenet/train.py
# Out:
# COMET ERROR: Failed to calculate active processors count. Fall back to default CPU count 1
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. You can override where Comet is looking for a Git Patch by setting the configuration `COMET_GIT_DIRECTORY`
# COMET INFO: Experiment is live on comet.com https://www.comet.com/teams-project/classfiy-project/cc4b822d904e4c7aac0dcc391c70b0c6
#
# using cuda:0 device.
# Using 2 dataloader workers every process
# using 2219 images for training, 248 images for validation.
# ...
# valid epoch[1/10]: 100%|██████████| 3/3 [00:16<00:00,  5.45s/it]
# [epoch 1] train_loss: 2.532  val_accuracy: 0.504
# ...
# valid epoch[2/10]: 100%|██████████| 3/3 [00:15<00:00,  5.33s/it]
# [epoch 2] train_loss: 1.335  val_accuracy: 0.778
# ...
# valid epoch[3/10]: 100%|██████████| 3/3 [00:16<00:00,  5.33s/it]
# [epoch 3] train_loss: 0.588  val_accuracy: 0.867
# ...
# valid epoch[4/10]: 100%|██████████| 3/3 [00:16<00:00,  5.37s/it]
# ...

# %%
# !python /content/drive/MyDrive/model/deep-learning-for-image-processing-master/pytorch_classification/Test6_mobilenet/predict.py
import matplotlib.pyplot as plt
from PIL import Image

img_path = "/content/drive/MyDrive/model/test/images.jpg"
img = Image.open(img_path)
plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# class: fiona                    prob: 1.21e-05
# class: 十二之卷                     prob: 5.59e-05
# class: 千佛手                      prob: 1.04e-05
# class: 千兔耳                      prob: 1.19e-05
# class: 墨西哥雪球                    prob: 1.8e-05
# class: 姬攏月                      prob: 1.18e-05
# class: 實生百合                     prob: 2.44e-05
# class: 月兔耳                      prob: 0.000152
# class: 桃蛋                       prob: 0.000316
# class: 沙漠玫瑰                     prob: 0.997
# class: 火祭                       prob: 8.12e-05
# class: 熊童子                      prob: 1.43e-05
# class: 白牡丹                      prob: 2.34e-05
# class: 石蓮                       prob: 0.000932
# class: 萬聖節法師                    prob: 0.00024
# class: 觀音蓮                      prob: 0.000231
# class: 達摩福娘                     prob: 6.93e-05
# class: 錦司晃                      prob: 1.65e-05
# class: 雅樂之舞                     prob: 0.000956
# class: 雪兔-麗娜蓮                   prob: 1.6e-05
# ...

# %% [markdown]
# ToTensor H，W，C ——> C，H，W C/255 [0~1]
#
# Normalize
# 用mean=[0.485, 0.456, 0.406] and std=[0.229, 0.224, 0.225]来正则化
# Normalize
#
# 等同先做一層BN
#
# 使用ImageNet的均值和标准差。
# 使用Imagenet的均值和标准差是一种常见的做法。它们是根据数百万张图像计算得出的。如果要在自己的数据集上从头开始训练，则可以计算新的均值和标准差。否则，建议使用Imagenet预设模型及其平均值和标准差。

# %% [markdown]
# 資料增強添加在
# data_transform
# 參考
# https://zhuanlan.zhihu.com/p/200876072
# https://blog.csdn.net/weixin_43593330/article/details/107516358
#
# Default value is 0.5
# optimizer = optim.Adam(params, lr=0.0001) lr: learning rate
#
#
# iteration = exampleNums ∗ epoch / batchsize
# ​
