# %% [markdown]
# <a href="https://colab.research.google.com/github/Howl06/practice/blob/main/tensorflow.keras/Hw_vessel_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

from PIL import Image
import os
from glob import glob
from tqdm.auto import tqdm

# data augmentation
import imgaug.augmenters as iaa
import imgaug as ia

import tensorflow as tf
from tensorflow.keras import *
import tensorflow.keras.backend as K

from sklearn.model_selection import train_test_split
import pandas as pd

# %% [markdown]
# #### Download data

# %%
# download dataset from https://drive.google.com/file/d/1JILW10sr40CRTLiuA1mf__5GBtMDF9xc/view?usp=sharing
# !gdown --fuzzy 1JILW10sr40CRTLiuA1mf__5GBtMDF9xc --output vessel_seg.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JILW10sr40CRTLiuA1mf__5GBtMDF9xc
# To: /content/vessel_seg.zip
# 100% 29.2M/29.2M [00:00<00:00, 184MB/s]

# %%
# unzip file
# !unzip -q vessel_seg.zip

# %% [markdown]
# #### Data Analysis

# %%
# read img and mask
img_paths = glob('all/train/*.tif')
img_path = np.random.choice(img_paths, size=1)[0]
mask_path = img_path.replace('_training.tif', '_manual1.gif')

print('img path: ', img_path)
print('mask path:',  mask_path)

img = cv2.imread(img_path)[:, :, ::-1] # BGR -> RGB
mask = Image.open(mask_path)
mask = np.array(mask)

img.shape, mask.shape
# Out:
# img path:  all/train/24_training.tif
# mask path: all/train/24_manual1.gif
# ((584, 565, 3), (584, 565))

# %%
len(img_paths)
# Out:
# 20

# %%
# show image
plt.figure(figsize=(20, 5))
plt.subplot(1,2,1)
plt.imshow(img)
plt.subplot(1,2,2)
plt.imshow(mask, cmap='gray')
# plt.imshow(mask)
plt.show()

# %%
img.shape, mask.shape
# Out:
# ((584, 565, 3), (584, 565))

# %%
np.unique(mask, return_counts=True)
# Out:
# (array([  0, 255], dtype=uint8), array([291731,  38229]))

# %% [markdown]
# #### Data processing

# %%
IMG_SIZE = 512 # 16X Kaggle: 512
BS = 4

# %%
class DataGenerator(utils.Sequence):
    def __init__(self, img_paths, batch_size, img_size, shuffle=True, 
                 mode='train', aug=False):
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.img_size = img_size
        self.mode = mode
        self.img_paths = img_paths
        self.mask_paths = [p.replace('_training.tif', '_manual1.gif') for p in self.img_paths]
        # same data augmentation(target , mask)
        self.aug = aug
        self.indexes = np.arange(len(self.mask_paths))
        self.seq = iaa.Sequential([
            iaa.Fliplr(0.5), # 50% horizontal flip
            iaa.Flipud(0.5),
            iaa.Affine(
                rotate=(90, -90), # random rotate -45 ~ +45 degree
                shear=(-3, 3), # random shear -3 ~ +3 degree
                scale={"x": (0.8, 1.2), "y": (0.8, 1.2)} # scale x, y: 80%~120%
            ),
        ])
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.mask_paths) / self.batch_size)) # batches per epoch

    def __getitem__(self, batch_index):
        # Generate indexes of the batch
        idxs = self.indexes[batch_index * self.batch_size:(batch_index + 1) * self.batch_size]
        # Find list of IDs
        batch_img_paths = [self.img_paths[i] for i in idxs]
        batch_mask_paths = [self.mask_paths[i] for i in idxs]

        # Generate data
        X, y = self.__data_generation(batch_img_paths, batch_mask_paths)
        if self.mode != 'test':
            return X, y
        else:
            return X

    def on_epoch_end(self):
        # Updates indexes after each epoch
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __data_generation(self, img_paths, mask_paths):
        # Generates data containing batch_size samples
        x = np.empty((len(img_paths), self.img_size, self.img_size, 3), dtype=np.float32)
        y = np.empty((len(img_paths), self.img_size, self.img_size, 1), dtype=np.float32)

        for i, (img_path, mask_path) in enumerate(zip(img_paths, mask_paths)):
            img = cv2.imread(img_path)[:, :, ::-1]
            img = self.preprocess(img) # 0~255 -> 0~1
            x[i] = img
            if self.mode != 'test':
                mask = np.array(Image.open(mask_path))
                mask = self.preprocess(mask) # 0 or 255 -> 0 or 1
                # torch squeeze
                y[i] = np.expand_dims(mask, axis=-1) # (512, 512) -> (512, 512, 1)
        # Augmentation
        if self.aug:
            x, y = self.seq(images=x, heatmaps=y) # imgaug
        return x, y

    def preprocess(self, img):
        data = cv2.resize(img, (self.img_size, self.img_size))
        data = data / 255. # normalize to 0~1
        return data

# %%
all_paths = glob('all/train/*.tif')
test_paths = sorted(glob('all/test/*.tif'))
train_paths, val_paths = train_test_split(all_paths, test_size=0.2)

train_gen = DataGenerator(train_paths, BS, IMG_SIZE, 
                          shuffle=True, mode='train', 
                          aug=True)
val_gen = DataGenerator(val_paths, BS, IMG_SIZE, shuffle=False, mode='val')

# %%
test_gen = DataGenerator(test_paths, BS, IMG_SIZE, shuffle=False, mode='test')

# %%
len(train_paths), len(val_paths)
# Out:
# (16, 4)

# %%
# Check output

batch_x, batch_y = train_gen[0]
print(batch_x.shape, batch_y.shape)

# batch_i = np.random.choice(len(batch_x))
batch_i = 0

plt.figure(figsize=(20, 5))
plt.subplot(1,2,1)
plt.imshow(batch_x[batch_i])
plt.subplot(1,2,2)
plt.imshow(batch_y[batch_i, :, :, 0], cmap='gray')
plt.show()
# Out:
# (4, 512, 512, 3) (4, 512, 512, 1)

# %% [markdown]
# #### Build model: U-Net

# %%
BASE_FILTERS = 8

# %%
def conv_bn(x, filters):
    x = layers.Conv2D(filters=filters, kernel_size=3, padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    return x

def inception(x, nb_filter):
    branch1x1 = layers.Conv2D(nb_filter, (1,1), padding='same', activation='relu')(x)

    branch3x3 = layers.Conv2D(nb_filter//4, (1,1), padding='same', activation='relu')(x)
    branch3x3 = layers.Conv2D(nb_filter, (3,3), padding='same', activation='relu')(branch3x3)
    
    branch5x5 = layers.Conv2D(nb_filter//4, (1,1), padding='same', activation='relu')(x)
    branch5x5 = layers.Conv2D(nb_filter, (5,5), padding='same', activation='relu')(branch5x5)
    
    branchpool = layers.MaxPooling2D(pool_size=(3,3), strides=(1,1), padding='same')(x)
    branchpool = layers.Conv2D(nb_filter//2, (1,1), padding='same', activation='relu')(branchpool)
    
    x = layers.concatenate([branch1x1, branch3x3, branch5x5, branchpool], axis=-1)
    return x

def identity_block(input_tensor, filters, kernel_size=3):
    """The identity block is the block that has no conv layer at shortcut.
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3, the kernel size of
            middle conv layer at main path
        filters: list of integers, the filters of 3 conv layer at main path
    """
    filters1, filters2, filters3 = filters # ex: [64, 64, 256]
    bn_axis = -1

    x = layers.Conv2D(filters1, (1, 1),
                      kernel_initializer='he_normal')(input_tensor)
    x = layers.BatchNormalization(axis=bn_axis)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size,
                      padding='same',
                      kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization(axis=bn_axis)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1),
                      kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization(axis=bn_axis)(x)

    x = layers.add([x, input_tensor]) # skip connection
    x = layers.Activation('relu')(x)
    return x
# strides 2
def conv_block(input_tensor,
               filters,
               kernel_size=3,
               strides=(2, 2)):
    """A block that has a conv layer at shortcut.
    # Arguments
        input_tensor: input tensor
        kernel_size: default 3, the kernel size of
            middle conv layer at main path
        filters: list of integers, the filters of 3 conv layer at main path
        strides: Strides for the first conv layer in the block.
    """
    filters1, filters2, filters3 = filters
    bn_axis = -1

    x = layers.Conv2D(filters1, (1, 1), strides=strides,
                      kernel_initializer='he_normal')(input_tensor)
    x = layers.BatchNormalization(axis=bn_axis)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters2, kernel_size, padding='same',
                      kernel_initializer='he_normal',)(x)
    x = layers.BatchNormalization(axis=bn_axis)(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters3, (1, 1),
                      kernel_initializer='he_normal')(x)
    x = layers.BatchNormalization(axis=bn_axis)(x)

    shortcut = layers.Conv2D(filters3, (1, 1), strides=strides,
                             kernel_initializer='he_normal')(input_tensor)
    shortcut = layers.BatchNormalization(axis=bn_axis)(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def build_model():

    # conv_bn = inception

    # Encoder
    input_layer = layers.Input(shape=(None, None, 3))
    # input_layer = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = conv_bn(input_layer, BASE_FILTERS)
    c1 = conv_bn(x, BASE_FILTERS)
    x = layers.MaxPool2D(strides=(2,2))(c1)
    x = conv_bn(x, BASE_FILTERS*2)
    c2 = conv_bn(x, BASE_FILTERS*2)
    x = layers.MaxPool2D(strides=(2,2))(c2)
    x = conv_bn(x, BASE_FILTERS*4)
    c3 = conv_bn(x, BASE_FILTERS*4)
    x = layers.MaxPool2D(strides=(2,2))(c3)
    x = conv_bn(x, BASE_FILTERS*8)
    c4 = conv_bn(x, BASE_FILTERS*8)

    # Decoder
    x = layers.concatenate([#layers.UpSampling2D(size=(2,2))(c4),
                            layers.Conv2DTranspose(32, 3, strides=2, padding='same')(c4),
                            c3], axis=-1)
    x = conv_bn(x, 32)
    x = conv_bn(x, 32)
    x = layers.concatenate([#layers.UpSampling2D(size=(2,2))(x), 
                            layers.Conv2DTranspose(32, 3, strides=2, padding='same')(x),
                            c2], axis=-1)
    x = conv_bn(x, 64)
    x = conv_bn(x, 64)
    x = layers.concatenate([#layers.UpSampling2D(size=(2,2))(x), 
                            layers.Conv2DTranspose(32, 3, strides=2, padding='same')(x),
                            c1], axis=-1)
    x = conv_bn(x, 128)
    x = conv_bn(x, 128)

    output_layer = layers.Conv2D(filters=1, kernel_size=(1,1), activation='sigmoid')(x)
                                                            
    model = models.Model(input_layer, output_layer)
    return model

# %%
def build_resunet():

    # [BASE_FILTERS, BASE_FILTERS, BASE_FILTERS*4]
    filters1 = [BASE_FILTERS, BASE_FILTERS, BASE_FILTERS*4]
    filters2 = [BASE_FILTERS*2, BASE_FILTERS*2, BASE_FILTERS*8]
    filters3 = [BASE_FILTERS*4, BASE_FILTERS*4, BASE_FILTERS*16]
    filters4 = [BASE_FILTERS*8, BASE_FILTERS*8, BASE_FILTERS*32]

    input_layer = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = conv_bn(input_layer, BASE_FILTERS*4)

    x = identity_block(x, filters1)
    c1 = identity_block(x, filters1)
    # x = layers.MaxPool2D(strides=(2,2))(c1)
    x = conv_block(c1, filters2)
    x = identity_block(x, filters2)
    c2 = identity_block(x, filters2)
    # x = layers.MaxPool2D(strides=(2,2))(c2)
    x = conv_block(c2, filters3)
    x = identity_block(x, filters3)
    c3 = identity_block(x, filters3)
    # x = layers.MaxPool2D(strides=(2,2))(c3)
    x = conv_block(c3, filters4)
    x = identity_block(x, filters4)
    c4 = identity_block(x, filters4)

    x = layers.concatenate([#layers.UpSampling2D(size=(2,2))(c4),
                            layers.Conv2DTranspose(32, 3, strides=2, padding='same')(c4),
                            c3], axis=-1)
    x = conv_bn(x, 32)
    x = conv_bn(x, 32)
    x = layers.concatenate([#layers.UpSampling2D(size=(2,2))(x), 
                            layers.Conv2DTranspose(32, 3, strides=2, padding='same')(x),
                            c2], axis=-1)
    x = conv_bn(x, 64)
    x = conv_bn(x, 64)
    x = layers.concatenate([#layers.UpSampling2D(size=(2,2))(x), 
                            layers.Conv2DTranspose(32, 3, strides=2, padding='same')(x),
                            c1], axis=-1)
    x = conv_bn(x, 128)
    x = conv_bn(x, 128)

    output_layer = layers.Conv2D(filters=1, kernel_size=(1,1), activation='sigmoid')(x)
                                                            
    model = models.Model(input_layer, output_layer)
    return model

# %%
def build_resunet_k2():

    # [BASE_FILTERS, BASE_FILTERS, BASE_FILTERS*4]
    filters1 = [BASE_FILTERS, BASE_FILTERS, BASE_FILTERS*4]
    filters2 = [BASE_FILTERS*2, BASE_FILTERS*2, BASE_FILTERS*8]
    filters3 = [BASE_FILTERS*4, BASE_FILTERS*4, BASE_FILTERS*16]
    filters4 = [BASE_FILTERS*8, BASE_FILTERS*8, BASE_FILTERS*32]

    input_layer = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = conv_bn(input_layer, BASE_FILTERS*4)

    x = identity_block(x, filters1)
    c1 = identity_block(x, filters1)
    # x = layers.MaxPool2D(strides=(2,2))(c1)
    x = conv_block(c1, filters2)
    x = identity_block(x, filters2)
    c2 = identity_block(x, filters2)
    # x = layers.MaxPool2D(strides=(2,2))(c2)
    x = conv_block(c2, filters3)
    x = identity_block(x, filters3)
    c3 = identity_block(x, filters3)
    # x = layers.MaxPool2D(strides=(2,2))(c3)
    x = conv_block(c3, filters4)
    x = identity_block(x, filters4)
    c4 = identity_block(x, filters4)

    x = layers.concatenate([#layers.UpSampling2D(size=(2,2))(c4),
                            layers.Conv2DTranspose(32, 2, strides=2, padding='same')(c4),
                            c3], axis=-1)
    x = conv_bn(x, 32)
    x = conv_bn(x, 32)
    x = layers.concatenate([#layers.UpSampling2D(size=(2,2))(x), 
                            layers.Conv2DTranspose(32, 2, strides=2, padding='same')(x),
                            c2], axis=-1)
    x = conv_bn(x, 64)
    x = conv_bn(x, 64)
    x = layers.concatenate([#layers.UpSampling2D(size=(2,2))(x), 
                            layers.Conv2DTranspose(32, 2, strides=2, padding='same')(x),
                            c1], axis=-1)
    x = conv_bn(x, 128)
    x = conv_bn(x, 128)

    output_layer = layers.Conv2D(filters=1, kernel_size=(1,1), activation='sigmoid')(x)
                                                            
    model = models.Model(input_layer, output_layer)
    return model

# %%
tf.keras.backend.clear_session()
# model = build_resunet()
model = build_resunet_k2()
# model = build_model()

# %%
model.summary() 
# resunet: 1,918,881, 
# incepunet: 4,197,601, 
# incepunet(update): 1,211,169
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 512, 512, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 8)  264         ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 8)  32         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation (Activation)        (None, 512, 512, 8)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 512, 512, 8)  584         ['activation[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 512, 512, 8)  32         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 512, 512, 8)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 512, 512, 32  288         ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 512, 512, 32  128        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  add (Add)                      (None, 512, 512, 32  0           ['batch_normalization_3[0][0]',
#                                 )                                 're_lu[0][0]']
#
#  activation_2 (Activation)      (None, 512, 512, 32  0           ['add[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 512, 512, 8)  264         ['activation_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 512, 512, 8)  32         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 512, 512, 8)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 512, 512, 8)  584         ['activation_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 512, 512, 8)  32         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 512, 512, 8)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 32  288         ['activation_4[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 512, 512, 32  128        ['conv2d_6[0][0]']
#  rmalization)                   )
#
#  add_1 (Add)                    (None, 512, 512, 32  0           ['batch_normalization_6[0][0]',
#                                 )                                 'activation_2[0][0]']
#
#  activation_5 (Activation)      (None, 512, 512, 32  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 16  528         ['activation_5[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 256, 256, 16  64         ['conv2d_7[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 256, 256, 16  2320        ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 256, 256, 16  64         ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 256, 256, 64  1088        ['activation_7[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 256, 256, 64  2112        ['activation_5[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 256, 256, 64  256        ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  batch_normalization_10 (BatchN  (None, 256, 256, 64  256        ['conv2d_10[0][0]']
#  ormalization)                  )
#
#  add_2 (Add)                    (None, 256, 256, 64  0           ['batch_normalization_9[0][0]',
#                                 )                                 'batch_normalization_10[0][0]']
#
#  activation_8 (Activation)      (None, 256, 256, 64  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 256, 256, 16  1040        ['activation_8[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 256, 256, 16  64         ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  activation_9 (Activation)      (None, 256, 256, 16  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 256, 256, 16  2320        ['activation_9[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 256, 256, 16  64         ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  activation_10 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 64  1088        ['activation_10[0][0]']
#                                 )
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 64  256        ['conv2d_13[0][0]']
#  ormalization)                  )
#
#  add_3 (Add)                    (None, 256, 256, 64  0           ['batch_normalization_13[0][0]',
#                                 )                                 'activation_8[0][0]']
#
#  activation_11 (Activation)     (None, 256, 256, 64  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 16  1040        ['activation_11[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 16  64         ['conv2d_14[0][0]']
#  ormalization)                  )
#
#  activation_12 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 16  64         ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  activation_13 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_15[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  1088        ['activation_13[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  add_4 (Add)                    (None, 256, 256, 64  0           ['batch_normalization_16[0][0]',
#                                 )                                 'activation_11[0][0]']
#
#  activation_14 (Activation)     (None, 256, 256, 64  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  2080        ['activation_14[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 32  128        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_15 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 32  9248        ['activation_15[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 32  128        ['conv2d_18[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_18[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 128, 128, 12  4224        ['activation_16[0][0]']
#                                 8)
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 12  8320        ['activation_14[0][0]']
#                                 8)
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 12  512        ['conv2d_19[0][0]']
#  ormalization)                  8)
#
#  batch_normalization_20 (BatchN  (None, 128, 128, 12  512        ['conv2d_20[0][0]']
#  ormalization)                  8)
#
#  add_5 (Add)                    (None, 128, 128, 12  0           ['batch_normalization_19[0][0]',
#                                 8)                                'batch_normalization_20[0][0]']
#
#  activation_17 (Activation)     (None, 128, 128, 12  0           ['add_5[0][0]']
#                                 8)
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 32  4128        ['activation_17[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 128, 128, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  activation_18 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 32  9248        ['activation_18[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 32  128        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 12  4224        ['activation_19[0][0]']
#                                 8)
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 12  512        ['conv2d_23[0][0]']
#  ormalization)                  8)
#
#  add_6 (Add)                    (None, 128, 128, 12  0           ['batch_normalization_23[0][0]',
#                                 8)                                'activation_17[0][0]']
#
#  activation_20 (Activation)     (None, 128, 128, 12  0           ['add_6[0][0]']
#                                 8)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 32  4128        ['activation_20[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 32  128        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_24[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 32  9248        ['activation_21[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 128, 128, 32  128        ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_25[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 12  4224        ['activation_22[0][0]']
#                                 8)
#
#  batch_normalization_26 (BatchN  (None, 128, 128, 12  512        ['conv2d_26[0][0]']
#  ormalization)                  8)
#
#  add_7 (Add)                    (None, 128, 128, 12  0           ['batch_normalization_26[0][0]',
#                                 8)                                'activation_20[0][0]']
#
#  activation_23 (Activation)     (None, 128, 128, 12  0           ['add_7[0][0]']
#                                 8)
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 64)   8256        ['activation_23[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 64, 64, 64)  256         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_24[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 64, 64, 64)  256         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 256)  16640       ['activation_25[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 256)  33024       ['activation_23[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_30[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 64, 64, 256)  0           ['batch_normalization_29[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_26 (Activation)     (None, 64, 64, 256)  0           ['add_8[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 64)   16448       ['activation_26[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 64)  256         ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_27[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 64)  256         ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 256)  16640       ['activation_28[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 64, 64, 256)  0           ['batch_normalization_33[0][0]',
#                                                                   'activation_26[0][0]']
#
#  activation_29 (Activation)     (None, 64, 64, 256)  0           ['add_9[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 64)   16448       ['activation_29[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 64, 64, 64)  256         ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_30[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 64, 64, 64)  256         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 64, 64, 256)  16640       ['activation_31[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 64, 64, 256)  0           ['batch_normalization_36[0][0]',
#                                                                   'activation_29[0][0]']
#
#  activation_32 (Activation)     (None, 64, 64, 256)  0           ['add_10[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 128, 128, 32  32800      ['activation_32[0][0]']
#  ose)                           )
#
#  concatenate (Concatenate)      (None, 128, 128, 16  0           ['conv2d_transpose[0][0]',
#                                 0)                                'activation_23[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 128, 128, 32  46112       ['concatenate[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 128, 128, 32  128        ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  re_lu_1 (ReLU)                 (None, 128, 128, 32  0           ['batch_normalization_37[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 128, 128, 32  9248        ['re_lu_1[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 128, 128, 32  128        ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  re_lu_2 (ReLU)                 (None, 128, 128, 32  0           ['batch_normalization_38[0][0]']
#                                 )
#
#  conv2d_transpose_1 (Conv2DTran  (None, 256, 256, 32  4128       ['re_lu_2[0][0]']
#  spose)                         )
#
#  concatenate_1 (Concatenate)    (None, 256, 256, 96  0           ['conv2d_transpose_1[0][0]',
#                                 )                                 'activation_14[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 64  55360       ['concatenate_1[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 256, 256, 64  256        ['conv2d_39[0][0]']
#  ormalization)                  )
#
#  re_lu_3 (ReLU)                 (None, 256, 256, 64  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 256, 256, 64  36928       ['re_lu_3[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 256, 256, 64  256        ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  re_lu_4 (ReLU)                 (None, 256, 256, 64  0           ['batch_normalization_40[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 512, 512, 32  8224       ['re_lu_4[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'activation_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 512, 512, 12  73856       ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_41 (BatchN  (None, 512, 512, 12  512        ['conv2d_41[0][0]']
#  ormalization)                  8)
#
#  re_lu_5 (ReLU)                 (None, 512, 512, 12  0           ['batch_normalization_41[0][0]']
#                                 8)
#
#  conv2d_42 (Conv2D)             (None, 512, 512, 12  147584      ['re_lu_5[0][0]']
#                                 8)
#
#  batch_normalization_42 (BatchN  (None, 512, 512, 12  512        ['conv2d_42[0][0]']
#  ormalization)                  8)
#
#  re_lu_6 (ReLU)                 (None, 512, 512, 12  0           ['batch_normalization_42[0][0]']
#                                 8)
#
#  conv2d_43 (Conv2D)             (None, 512, 512, 1)  129         ['re_lu_6[0][0]']
#
# ==================================================================================================
# Total params: 738,593
# Trainable params: 732,513
# Non-trainable params: 6,080
# __________________________________________________________________________________________________

# %%
utils.plot_model(model, show_shapes=True)

# %%
utils.plot_model(model, show_shapes=True)

# %% [markdown]
# #### Training

# %%
# Customize Dice coefficient
# K = tf.keras.backend

# range: 0 ~ 1
def dice_coef(y_true, y_pred):
    # y_true_f = K.flatten(y_true)
    # y_pred_f = K.flatten(y_pred)

    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])

    # intersection = K.sum(y_true_f * y_pred_f)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    y_true_f = tf.reduce_sum(y_true_f)
    y_pred_f = tf.reduce_sum(y_pred_f)
    return (2. * intersection) / (y_true_f + y_pred_f + 1e-7) # 1e-6, 1e-7

# Customized loss function
# range: 1 ~ 0
def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

# IoULoss

# %%
model.compile(optimizer=optimizers.AdamW(), 
              loss='binary_crossentropy', 
               # loss=dice_loss,
              metrics=[dice_coef]
              
              )

# %%
weight_saver = callbacks.ModelCheckpoint('seg.h5', 
                                         save_best_only=True)
earlystop = callbacks.EarlyStopping(patience=50)

# %%
logs = model.fit(train_gen,
                 validation_data = val_gen,
                 epochs=100,
                 callbacks = [weight_saver, earlystop])
# Out:
# Epoch 1/100
# 4/4 [==============================] - 3s 899ms/step - loss: 0.0834 - dice_coef: 0.6843 - val_loss: 0.1003 - val_dice_coef: 0.6976
# Epoch 2/100
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0901 - dice_coef: 0.6813 - val_loss: 0.1014 - val_dice_coef: 0.6923
# Epoch 3/100
# 4/4 [==============================] - 3s 727ms/step - loss: 0.0916 - dice_coef: 0.6737 - val_loss: 0.1047 - val_dice_coef: 0.6870
# Epoch 4/100
# 4/4 [==============================] - 3s 851ms/step - loss: 0.0924 - dice_coef: 0.6757 - val_loss: 0.1046 - val_dice_coef: 0.6858
# Epoch 5/100
# 4/4 [==============================] - 3s 725ms/step - loss: 0.0915 - dice_coef: 0.6760 - val_loss: 0.1048 - val_dice_coef: 0.6908
# Epoch 6/100
# 4/4 [==============================] - 3s 723ms/step - loss: 0.0885 - dice_coef: 0.6834 - val_loss: 0.1066 - val_dice_coef: 0.6991
# Epoch 7/100
# 4/4 [==============================] - 3s 718ms/step - loss: 0.0881 - dice_coef: 0.6812 - val_loss: 0.1226 - val_dice_coef: 0.6575
# Epoch 8/100
# 4/4 [==============================] - 3s 736ms/step - loss: 0.0911 - dice_coef: 0.6711 - val_loss: 0.1097 - val_dice_coef: 0.6846
# Epoch 9/100
# 4/4 [==============================] - 3s 701ms/step - loss: 0.0902 - dice_coef: 0.6830 - val_loss: 0.1033 - val_dice_coef: 0.7033
# Epoch 10/100
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0953 - dice_coef: 0.6763 - val_loss: 0.1072 - val_dice_coef: 0.6717
# Epoch 11/100
# 4/4 [==============================] - 3s 828ms/step - loss: 0.0933 - dice_coef: 0.6771 - val_loss: 0.1092 - val_dice_coef: 0.6734
# Epoch 12/100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-7b821158128f> in <cell line: 1>()
# ----> 1 logs = model.fit(train_gen,
#       2                  validation_data = val_gen,
#       3                  epochs=100,
#       4                  callbacks = [weight_saver, earlystop])
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1689                             logs = tmp_logs
#    1690                             end_step = step + data_handler.step_increment
# -> 1691                             callbacks.on_train_batch_end(end_step, logs)
#    1692                             if self.stop_training:
#    1693                                 break
#
# /usr/local/lib/python3.10/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.10/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.10/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1167         if self.verbose == 1:
#    1168             # Only block async when verbose = 1.
# -> 1169             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1171
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     678         return t.item() if np.ndim(t) == 0 else t
#     679
# --> 680     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     681
#     682
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     915
#     916   return pack_sequence_as(
# --> 917       structure[0], [func(*x) for x in entries],
#     918       expand_composites=expand_composites)
#     919
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     671         # Don't turn ragged or sparse tensors to NumPy.
#     672         if isinstance(t, tf.Tensor):
# --> 673             t = t.numpy()
#     674         # Strings, ragged and sparse tensors don't have .item(). Return them
#     675         # as-is.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1158     """
#    1159     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1160     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1161     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1162
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1124   def _numpy(self):
#    1125     try:
# -> 1126       return self._numpy_internal()
#    1127     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1128       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
logs = model.fit(train_gen,
                 validation_data = val_gen,
                 epochs=1000,
                 initial_epoch=0,
                 callbacks = [weight_saver, earlystop])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 37s 2s/step - loss: 0.6582 - dice_coef: 0.1476 - val_loss: 0.6763 - val_dice_coef: 0.1662
# Epoch 2/1000
# 4/4 [==============================] - 3s 877ms/step - loss: 0.3669 - dice_coef: 0.1752 - val_loss: 0.6123 - val_dice_coef: 0.1620
# Epoch 3/1000
# 4/4 [==============================] - 3s 729ms/step - loss: 0.2817 - dice_coef: 0.1596 - val_loss: 0.6263 - val_dice_coef: 0.1678
# Epoch 4/1000
# 4/4 [==============================] - 3s 892ms/step - loss: 0.2548 - dice_coef: 0.1841 - val_loss: 0.5897 - val_dice_coef: 0.1665
# Epoch 5/1000
# 4/4 [==============================] - 3s 893ms/step - loss: 0.2358 - dice_coef: 0.2059 - val_loss: 0.5435 - val_dice_coef: 0.1655
# Epoch 6/1000
# 4/4 [==============================] - 4s 971ms/step - loss: 0.2221 - dice_coef: 0.2223 - val_loss: 0.5095 - val_dice_coef: 0.1634
# Epoch 7/1000
# 4/4 [==============================] - 4s 908ms/step - loss: 0.2081 - dice_coef: 0.2656 - val_loss: 0.4500 - val_dice_coef: 0.1551
# Epoch 8/1000
# 4/4 [==============================] - 3s 898ms/step - loss: 0.1946 - dice_coef: 0.3186 - val_loss: 0.4004 - val_dice_coef: 0.1466
# Epoch 9/1000
# 4/4 [==============================] - 3s 889ms/step - loss: 0.2040 - dice_coef: 0.3330 - val_loss: 0.3549 - val_dice_coef: 0.1206
# Epoch 10/1000
# 4/4 [==============================] - 3s 740ms/step - loss: 0.1783 - dice_coef: 0.3615 - val_loss: 0.3678 - val_dice_coef: 0.1276
# Epoch 11/1000
# 4/4 [==============================] - 3s 715ms/step - loss: 0.1783 - dice_coef: 0.3875 - val_loss: 0.3574 - val_dice_coef: 0.1247
# Epoch 12/1000
# 4/4 [==============================] - 3s 711ms/step - loss: 0.1745 - dice_coef: 0.3956 - val_loss: 0.3775 - val_dice_coef: 0.0947
# Epoch 13/1000
# 4/4 [==============================] - 3s 711ms/step - loss: 0.1716 - dice_coef: 0.4110 - val_loss: 0.3852 - val_dice_coef: 0.0890
# Epoch 14/1000
# 4/4 [==============================] - 3s 834ms/step - loss: 0.1634 - dice_coef: 0.4161 - val_loss: 0.3778 - val_dice_coef: 0.0844
# Epoch 15/1000
# 4/4 [==============================] - 3s 695ms/step - loss: 0.1690 - dice_coef: 0.4455 - val_loss: 0.3830 - val_dice_coef: 0.0799
# Epoch 16/1000
# 4/4 [==============================] - 3s 702ms/step - loss: 0.1525 - dice_coef: 0.4709 - val_loss: 0.3954 - val_dice_coef: 0.0481
# Epoch 17/1000
# 4/4 [==============================] - 3s 699ms/step - loss: 0.1548 - dice_coef: 0.4780 - val_loss: 0.3824 - val_dice_coef: 0.0521
# Epoch 18/1000
# 4/4 [==============================] - 3s 876ms/step - loss: 0.1523 - dice_coef: 0.4763 - val_loss: 0.3410 - val_dice_coef: 0.0798
# 4/4 [==============================] - 3s 843ms/step - loss: 0.0923 - dice_coef: 0.6739 - val_loss: 0.1067 - val_dice_coef: 0.7005
# Epoch 208/1000
# 4/4 [==============================] - 3s 896ms/step - loss: 0.0851 - dice_coef: 0.6888 - val_loss: 0.1035 - val_dice_coef: 0.6911
# Epoch 209/1000
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0881 - dice_coef: 0.6741 - val_loss: 0.1060 - val_dice_coef: 0.6772
# Epoch 210/1000
# 4/4 [==============================] - 3s 716ms/step - loss: 0.0997 - dice_coef: 0.6753 - val_loss: 0.1073 - val_dice_coef: 0.6916
# Epoch 211/1000
# 4/4 [==============================] - 3s 705ms/step - loss: 0.0958 - dice_coef: 0.6828 - val_loss: 0.1185 - val_dice_coef: 0.6672
# Epoch 212/1000
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0925 - dice_coef: 0.6768 - val_loss: 0.1041 - val_dice_coef: 0.6915
# Epoch 213/1000
# 4/4 [==============================] - 3s 893ms/step - loss: 0.0983 - dice_coef: 0.6839 - val_loss: 0.1024 - val_dice_coef: 0.6956
# Epoch 214/1000
# 4/4 [==============================] - 3s 736ms/step - loss: 0.0867 - dice_coef: 0.6830 - val_loss: 0.1059 - val_dice_coef: 0.6858
# Epoch 215/1000
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0899 - dice_coef: 0.6789 - val_loss: 0.1063 - val_dice_coef: 0.6918
# Epoch 216/1000
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0938 - dice_coef: 0.6799 - val_loss: 0.1125 - val_dice_coef: 0.6666
# Epoch 217/1000
# 4/4 [==============================] - 3s 709ms/step - loss: 0.0931 - dice_coef: 0.6758 - val_loss: 0.1093 - val_dice_coef: 0.6695
# Epoch 218/1000
# 4/4 [==============================] - 3s 732ms/step - loss: 0.0946 - dice_coef: 0.6839 - val_loss: 0.1049 - val_dice_coef: 0.6873
# Epoch 219/1000
# 4/4 [==============================] - 3s 716ms/step - loss: 0.0838 - dice_coef: 0.6837 - val_loss: 0.1107 - val_dice_coef: 0.6724
# Epoch 220/1000
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0909 - dice_coef: 0.6746 - val_loss: 0.1117 - val_dice_coef: 0.6904
# Epoch 221/1000
# 4/4 [==============================] - 3s 718ms/step - loss: 0.0892 - dice_coef: 0.6855 - val_loss: 0.1046 - val_dice_coef: 0.7003
# Epoch 222/1000
# 4/4 [==============================] - 3s 839ms/step - loss: 0.0913 - dice_coef: 0.6767 - val_loss: 0.1063 - val_dice_coef: 0.6992
# Epoch 223/1000
# 4/4 [==============================] - 3s 714ms/step - loss: 0.0915 - dice_coef: 0.6814 - val_loss: 0.1038 - val_dice_coef: 0.6988
# Epoch 224/1000
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0852 - dice_coef: 0.6820 - val_loss: 0.1140 - val_dice_coef: 0.6480
# Epoch 225/1000
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0839 - dice_coef: 0.6795 - val_loss: 0.1093 - val_dice_coef: 0.6687
# Epoch 245/1000
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0904 - dice_coef: 0.6781 - val_loss: 0.1266 - val_dice_coef: 0.6733
# Epoch 246/1000
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0937 - dice_coef: 0.6701 - val_loss: 0.1314 - val_dice_coef: 0.6701
# Epoch 247/1000
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0992 - dice_coef: 0.6693 - val_loss: 0.1148 - val_dice_coef: 0.6958
# Epoch 248/1000
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0910 - dice_coef: 0.6813 - val_loss: 0.1116 - val_dice_coef: 0.6868
# Epoch 249/1000
# 4/4 [==============================] - 3s 737ms/step - loss: 0.0900 - dice_coef: 0.6782 - val_loss: 0.1099 - val_dice_coef: 0.6787
# Epoch 250/1000
# 4/4 [==============================] - 3s 709ms/step - loss: 0.0925 - dice_coef: 0.6760 - val_loss: 0.1064 - val_dice_coef: 0.6833
# Epoch 251/1000
# 4/4 [==============================] - 3s 714ms/step - loss: 0.0913 - dice_coef: 0.6788 - val_loss: 0.1101 - val_dice_coef: 0.6849
# Epoch 252/1000
# 4/4 [==============================] - 3s 728ms/step - loss: 0.0921 - dice_coef: 0.6809 - val_loss: 0.1071 - val_dice_coef: 0.6852
# Epoch 253/1000
# 4/4 [==============================] - 3s 702ms/step - loss: 0.0889 - dice_coef: 0.6791 - val_loss: 0.1086 - val_dice_coef: 0.6884
# Epoch 254/1000
# 4/4 [==============================] - 3s 706ms/step - loss: 0.0903 - dice_coef: 0.6792 - val_loss: 0.1120 - val_dice_coef: 0.6947
# Epoch 255/1000
# 4/4 [==============================] - 3s 724ms/step - loss: 0.0899 - dice_coef: 0.6835 - val_loss: 0.1249 - val_dice_coef: 0.6694
# Epoch 256/1000
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0914 - dice_coef: 0.6698 - val_loss: 0.1071 - val_dice_coef: 0.6915
# Epoch 257/1000
# 4/4 [==============================] - 3s 880ms/step - loss: 0.0895 - dice_coef: 0.6819 - val_loss: 0.1022 - val_dice_coef: 0.7044
# Epoch 258/1000
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0852 - dice_coef: 0.6867 - val_loss: 0.1036 - val_dice_coef: 0.6859
# Epoch 259/1000
# 4/4 [==============================] - 4s 968ms/step - loss: 0.0876 - dice_coef: 0.6776 - val_loss: 0.1003 - val_dice_coef: 0.6949
# Epoch 260/1000
# 4/4 [==============================] - 3s 890ms/step - loss: 0.0905 - dice_coef: 0.6826 - val_loss: 0.0994 - val_dice_coef: 0.7049
# Epoch 261/1000
# 4/4 [==============================] - 3s 718ms/step - loss: 0.0923 - dice_coef: 0.6833 - val_loss: 0.1026 - val_dice_coef: 0.6985
# Epoch 262/1000
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0882 - dice_coef: 0.6806 - val_loss: 0.1039 - val_dice_coef: 0.6962
# Epoch 263/1000
# 4/4 [==============================] - 3s 744ms/step - loss: 0.0889 - dice_coef: 0.6804 - val_loss: 0.1111 - val_dice_coef: 0.6881
# Epoch 264/1000
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0894 - dice_coef: 0.6879 - val_loss: 0.1073 - val_dice_coef: 0.6829
# Epoch 265/1000
# 4/4 [==============================] - 3s 717ms/step - loss: 0.0944 - dice_coef: 0.6825 - val_loss: 0.1069 - val_dice_coef: 0.6765
# Epoch 266/1000
# 4/4 [==============================] - 3s 732ms/step - loss: 0.0906 - dice_coef: 0.6816 - val_loss: 0.1018 - val_dice_coef: 0.7035
# Epoch 267/1000
# 4/4 [==============================] - 3s 704ms/step - loss: 0.0948 - dice_coef: 0.6859 - val_loss: 0.1082 - val_dice_coef: 0.6997
# Epoch 268/1000
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0862 - dice_coef: 0.6864 - val_loss: 0.1060 - val_dice_coef: 0.6889
# Epoch 269/1000
# 4/4 [==============================] - 3s 707ms/step - loss: 0.0890 - dice_coef: 0.6804 - val_loss: 0.1050 - val_dice_coef: 0.6787
# Epoch 270/1000
# 4/4 [==============================] - 3s 738ms/step - loss: 0.0909 - dice_coef: 0.6779 - val_loss: 0.1122 - val_dice_coef: 0.6946
# Epoch 271/1000
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0882 - dice_coef: 0.6882 - val_loss: 0.1014 - val_dice_coef: 0.7058
# Epoch 272/1000
# 4/4 [==============================] - 3s 721ms/step - loss: 0.0941 - dice_coef: 0.6877 - val_loss: 0.1074 - val_dice_coef: 0.6850
# Epoch 273/1000
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0886 - dice_coef: 0.6811 - val_loss: 0.1049 - val_dice_coef: 0.6861
# Epoch 274/1000
# 4/4 [==============================] - 3s 730ms/step - loss: 0.0886 - dice_coef: 0.6776 - val_loss: 0.1028 - val_dice_coef: 0.6841
# Epoch 275/1000
# 4/4 [==============================] - 3s 721ms/step - loss: 0.0878 - dice_coef: 0.6848 - val_loss: 0.1162 - val_dice_coef: 0.6761
# Epoch 276/1000
# 4/4 [==============================] - 3s 709ms/step - loss: 0.0924 - dice_coef: 0.6892 - val_loss: 0.1161 - val_dice_coef: 0.6758
# Epoch 277/1000
# 4/4 [==============================] - 3s 718ms/step - loss: 0.0907 - dice_coef: 0.6872 - val_loss: 0.1030 - val_dice_coef: 0.6833
# Epoch 278/1000
# 4/4 [==============================] - 3s 735ms/step - loss: 0.0864 - dice_coef: 0.6847 - val_loss: 0.1016 - val_dice_coef: 0.6941
# Epoch 279/1000
# 4/4 [==============================] - 3s 720ms/step - loss: 0.0915 - dice_coef: 0.6876 - val_loss: 0.1046 - val_dice_coef: 0.6977
# Epoch 280/1000
# 4/4 [==============================] - 3s 715ms/step - loss: 0.0945 - dice_coef: 0.6840 - val_loss: 0.1020 - val_dice_coef: 0.6958
# Epoch 281/1000
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0896 - dice_coef: 0.6818 - val_loss: 0.1025 - val_dice_coef: 0.6901
# Epoch 282/1000
# 4/4 [==============================] - 3s 730ms/step - loss: 0.0909 - dice_coef: 0.6843 - val_loss: 0.0999 - val_dice_coef: 0.6996
# Epoch 283/1000
# 4/4 [==============================] - 3s 722ms/step - loss: 0.0858 - dice_coef: 0.6910 - val_loss: 0.1021 - val_dice_coef: 0.6889
# Epoch 284/1000
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0890 - dice_coef: 0.6853 - val_loss: 0.1052 - val_dice_coef: 0.6865
# Epoch 285/1000
# 4/4 [==============================] - 3s 717ms/step - loss: 0.0910 - dice_coef: 0.6873 - val_loss: 0.1061 - val_dice_coef: 0.6860
# Epoch 286/1000
# 4/4 [==============================] - 3s 719ms/step - loss: 0.0936 - dice_coef: 0.6826 - val_loss: 0.1072 - val_dice_coef: 0.6778
# Epoch 287/1000
# 4/4 [==============================] - 3s 733ms/step - loss: 0.0934 - dice_coef: 0.6800 - val_loss: 0.1110 - val_dice_coef: 0.6705
# Epoch 288/1000
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0892 - dice_coef: 0.6857 - val_loss: 0.1144 - val_dice_coef: 0.6896
# Epoch 289/1000
# 4/4 [==============================] - 3s 711ms/step - loss: 0.0922 - dice_coef: 0.6811 - val_loss: 0.1038 - val_dice_coef: 0.6914
# Epoch 290/1000
# 4/4 [==============================] - 3s 714ms/step - loss: 0.0891 - dice_coef: 0.6841 - val_loss: 0.1019 - val_dice_coef: 0.7046
# Epoch 291/1000
# 4/4 [==============================] - 3s 739ms/step - loss: 0.0888 - dice_coef: 0.6934 - val_loss: 0.1219 - val_dice_coef: 0.6952
# Epoch 292/1000
# 4/4 [==============================] - 3s 701ms/step - loss: 0.0909 - dice_coef: 0.6789 - val_loss: 0.1110 - val_dice_coef: 0.6788
# Epoch 293/1000
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0888 - dice_coef: 0.6804 - val_loss: 0.1040 - val_dice_coef: 0.7136
# Epoch 294/1000
# 4/4 [==============================] - 3s 726ms/step - loss: 0.0880 - dice_coef: 0.6906 - val_loss: 0.1007 - val_dice_coef: 0.7081
# Epoch 295/1000
# 4/4 [==============================] - 3s 706ms/step - loss: 0.0968 - dice_coef: 0.6854 - val_loss: 0.1021 - val_dice_coef: 0.7000
# Epoch 296/1000
# 4/4 [==============================] - 3s 713ms/step - loss: 0.0891 - dice_coef: 0.6904 - val_loss: 0.1011 - val_dice_coef: 0.7043
# Epoch 297/1000
# 4/4 [==============================] - 3s 722ms/step - loss: 0.0817 - dice_coef: 0.6899 - val_loss: 0.1034 - val_dice_coef: 0.6885
# Epoch 298/1000
# 4/4 [==============================] - 3s 745ms/step - loss: 0.0872 - dice_coef: 0.6849 - val_loss: 0.1058 - val_dice_coef: 0.6814
# Epoch 299/1000
# 4/4 [==============================] - 3s 718ms/step - loss: 0.0903 - dice_coef: 0.6917 - val_loss: 0.1025 - val_dice_coef: 0.7037
# Epoch 300/1000
# 4/4 [==============================] - 3s 717ms/step - loss: 0.0851 - dice_coef: 0.6909 - val_loss: 0.1007 - val_dice_coef: 0.6985
# Epoch 301/1000
# 4/4 [==============================] - 3s 719ms/step - loss: 0.0881 - dice_coef: 0.6834 - val_loss: 0.1030 - val_dice_coef: 0.6958
# Epoch 302/1000
# 4/4 [==============================] - 3s 742ms/step - loss: 0.0858 - dice_coef: 0.6894 - val_loss: 0.1026 - val_dice_coef: 0.7133
# Epoch 303/1000
# 4/4 [==============================] - 3s 702ms/step - loss: 0.0942 - dice_coef: 0.6884 - val_loss: 0.1034 - val_dice_coef: 0.6945
# Epoch 304/1000
# 4/4 [==============================] - 3s 716ms/step - loss: 0.0841 - dice_coef: 0.6815 - val_loss: 0.1042 - val_dice_coef: 0.6955
# Epoch 305/1000
# 4/4 [==============================] - 3s 734ms/step - loss: 0.0837 - dice_coef: 0.6895 - val_loss: 0.1042 - val_dice_coef: 0.7001
# Epoch 306/1000
# 4/4 [==============================] - 3s 703ms/step - loss: 0.0884 - dice_coef: 0.6904 - val_loss: 0.1065 - val_dice_coef: 0.6871
# Epoch 307/1000
# 4/4 [==============================] - 3s 710ms/step - loss: 0.0848 - dice_coef: 0.6840 - val_loss: 0.1057 - val_dice_coef: 0.6954
# Epoch 308/1000
# 4/4 [==============================] - 3s 712ms/step - loss: 0.0903 - dice_coef: 0.6877 - val_loss: 0.1026 - val_dice_coef: 0.7035
# Epoch 309/1000
# 4/4 [==============================] - 3s 745ms/step - loss: 0.0908 - dice_coef: 0.6898 - val_loss: 0.1003 - val_dice_coef: 0.7033
# Epoch 310/1000
# 4/4 [==============================] - 3s 716ms/step - loss: 0.0838 - dice_coef: 0.6885 - val_loss: 0.1020 - val_dice_coef: 0.6996

# %% [markdown]
# #### Evaluate

# %%
history = logs.history
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('loss')
plt.show()
plt.plot(history['dice_coef'])
plt.plot(history['val_dice_coef'])
plt.title('Dice')
plt.show()

# %%
model_final = models.load_model('seg.h5', compile=False)

# %%
# Sample 1 batch
batch_idx = np.random.randint(len(val_gen))
print(batch_idx)
data = val_gen[batch_idx]
imgs, mask = data # (bs, 512, 512, 3), (bs, 512, 512, 1)
mask_pred = model_final.predict(imgs)

# show inputs
img_idx = np.random.randint(len(imgs)) # sample 1 image from batch
plt.figure(figsize=(20, 5))
plt.subplot(1,3,1)
plt.imshow(imgs[img_idx])
plt.title('Input')

# show ground truth & model prediction
plt.subplot(1, 3, 2)
plt.imshow(mask[img_idx, :, :, 0])
plt.title('Truth')
plt.subplot(1, 3, 3)
plt.imshow(mask_pred[img_idx, :, :, 0])
plt.title('Pred')
plt.show()
# plt.imshow(mask_pred[img_idx, :, :, 0], cmap='gray')
# Out:
# 0
# 1/1 [==============================] - 1s 1s/step

# %%
# Displayed with different threshold
mask_pred_raw = mask_pred[img_idx, :, :, 0]
mask_pred_raw
# Out:
# array([[0.00309235, 0.00184876, 0.00117766, ..., 0.00111368, 0.00214457,
#         0.0037219 ],
#        [0.00212659, 0.00071295, 0.00032596, ..., 0.00031572, 0.00055171,
#         0.00194796],
#        [0.00134518, 0.00027317, 0.00014351, ..., 0.00014418, 0.00025024,
#         0.0009889 ],
#        ...,
#        [0.00137135, 0.00034058, 0.0001585 , ..., 0.00014295, 0.00028113,
#         0.00120057],
#        [0.00274709, 0.00075663, 0.00034385, ..., 0.00032274, 0.00067192,
#         0.00177281],
#        [0.00370364, 0.00180118, 0.00110055, ..., 0.00106633, 0.00170349,
#         0.00266344]], dtype=float32)

# %%
# threshold 0.1 ~ 0.9
plt.imshow(mask[img_idx, :, :, 0])
plt.title('Ground Truth')
plt.show()

plt.figure(figsize=(20, 10))
for i in range(1, 10):
    plt.subplot(2, 5, i)
    threshold = i * 0.1
    mask_threshold = mask_pred_raw.copy()
    mask_threshold[mask_threshold <= threshold] = 0.
    mask_threshold[mask_threshold > threshold] = 1.
    plt.imshow(mask_threshold)
    plt.title(f'threshold: {threshold:.1f}')
plt.show()

# %% [markdown]
# #### Make Kaggle prediction
#
# https://www.kaggle.com/c/sai-vessel-segmentation2

# %%
# make prediction
threshold = 0.3 # 0.5
outputs = []
for i in range(len(test_gen)):
    x_test = test_gen[i]
    y_preds = model_final.predict(x_test)
    y_preds[y_preds <= threshold] = 0
    y_preds[y_preds > threshold] = 1
    for y_pred in y_preds:
        dots = np.where(y_pred.flatten() == 1)[0]
        run_lengths = []
        prev = -2
        for b in dots:
            if (b > prev +1):
                run_lengths.extend((b+1,0))
            run_lengths[-1] += 1
            prev = b
        output = ' '.join([str(r) for r in run_lengths])
        outputs.append(output)
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step

# %%
df = pd.DataFrame(columns=['Id', 'Predicted'])
df['Id'] = [str(i) for i in range(20)]
df['Predicted'] = outputs
df.to_csv('submission.csv', index=None)
df
# Out:
#     Id                                          Predicted
# 0    0  15108 6 15590 7 15620 6 15651 3 16102 7 16133 ...
# 1    1  15104 3 15615 8 16127 9 16142 6 16640 9 16654 ...
# 2    2  12555 9 13065 10 13577 10 14088 9 14543 2 1459...
# 3    3  13046 5 13558 6 14070 7 14583 7 15096 6 15608 ...
# 4    4  16131 2 16640 6 16676 2 17150 8 17186 5 17661 ...
# 5    5  16126 4 16638 3 17150 4 17190 2 17663 3 17701 ...
# 6    6  15630 4 16101 8 16141 6 16609 12 16653 6 17121...
# 7    7  15078 5 15122 2 15590 7 15632 5 16103 7 16143 ...
# 8    8  14577 1 15088 6 15123 6 15600 7 15609 3 15634 ...
# 9    9  15615 2 16126 5 16600 5 16638 6 17111 7 17151 ...
# 10  10  16125 2 16601 7 16637 2 17108 13 17149 2 17614...
# 11  11  15079 4 15590 7 15638 6 16102 7 16150 5 16614 ...
# 12  12  16095 3 16136 3 16607 4 16647 7 16668 4 17119 ...
# 13  13  13082 4 13593 6 14105 7 14562 3 14618 5 15058 ...
# 14  14  15111 3 15581 3 15622 5 16092 5 16134 5 16152 ...
# 15  15  15627 8 16139 8 16651 7 16682 4 17164 7 17194 ...
# 16  16  16608 3 17119 5 17631 5 17701 8 18144 4 18213 ...
# 17  17  15619 4 16128 8 16639 9 17151 7 17662 6 18173 ...
# 18  18  14594 2 15104 5 15617 5 16129 6 16642 5 17154 ...
# 19  19  16613 11 16627 4 17125 12 17140 3 17637 13 176...
