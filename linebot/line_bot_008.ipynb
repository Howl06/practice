# %%
'''

資料 mapping 至google drive

把資料寫在/content/drive

即可保存在 google drive內

'''
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
'''

'''

# !pip install line-bot-sdk flask flask-ngrok
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: line-bot-sdk in /usr/local/lib/python3.9/dist-packages (2.4.2)
# Requirement already satisfied: flask in /usr/local/lib/python3.9/dist-packages (2.2.3)
# Requirement already satisfied: flask-ngrok in /usr/local/lib/python3.9/dist-packages (0.0.25)
# Requirement already satisfied: aiohttp==3.8.4 in /usr/local/lib/python3.9/dist-packages (from line-bot-sdk) (3.8.4)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from line-bot-sdk) (0.16.0)
# Requirement already satisfied: requests==2.28.2 in /usr/local/lib/python3.9/dist-packages (from line-bot-sdk) (2.28.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.4->line-bot-sdk) (4.0.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.4->line-bot-sdk) (3.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.4->line-bot-sdk) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.4->line-bot-sdk) (22.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.4->line-bot-sdk) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.4->line-bot-sdk) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp==3.8.4->line-bot-sdk) (6.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests==2.28.2->line-bot-sdk) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests==2.28.2->line-bot-sdk) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests==2.28.2->line-bot-sdk) (2022.12.7)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from flask) (6.0.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from flask) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from flask) (8.1.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from flask) (2.2.3)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from flask) (3.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6.0->flask) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=3.0->flask) (2.1.2)

# %%
'''
引用套件
'''

# 引用Web Server套件
from flask import Flask, request, abort, jsonify

# 載入json處理套件
import json

# 外部連結自動生成套件
from flask_ngrok import run_with_ngrok

# 從linebot 套件包裡引用 LineBotApi 與 WebhookHandler 類別
from linebot import (
    LineBotApi, WebhookHandler
)

# 引用無效簽章錯誤
from linebot.exceptions import (
    InvalidSignatureError
)

# %%
# 設定Server啟用細節
app = Flask(__name__,static_url_path = "/素材" , static_folder = "./素材/")
run_with_ngrok(app)

# 生成實體物件
# 跟line 溝通用
line_bot_api = LineBotApi("vtaRo4pkLqIZjk50gBJ53fFtMpg+8unl4TvLKbyvENmbWkzdriMNIeVm87ZWRBdTeDL7YM4hGte+BrNMmYscJ1WNPvCQbheXUbVevrlKB3zP3CaeRjbPQRPHMsqW+037bLOogqjOrh5ssRj53kqQMQdB04t89/1O/w1cDnyilFU=")
# 收發訊息用
handler = WebhookHandler("de385af73d2121e65ca6fc0490991b02")

# %%
# 啟動server對外接口，使Line能丟消息進來
@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        abort(400)

    return 'OK'

# %%
'''
消息判斷器
讀取指定的json檔案後，把json解析成不同格式的SendMessage
讀取檔案，
把內容轉換成json
將json轉換成消息
放回array中，並把array傳出。
'''

# 引用會用到的套件
from linebot.models import (
    ImagemapSendMessage, TextSendMessage, ImageSendMessage, LocationSendMessage,
    FlexSendMessage, VideoSendMessage, StickerSendMessage, AudioSendMessage
)

from linebot.models.template import (
    ButtonsTemplate,CarouselTemplate,ConfirmTemplate,ImageCarouselTemplate
    
)

from linebot.models.template import *

def detect_json_array_to_new_message_array(fileName):
    
    #開啟檔案，轉成json
    with open(fileName,encoding='utf8') as f:
        jsonArray = json.load(f)
    """
    先做一個array
    判斷消息,判斷裡面的json的type欄位
    依據type欄位轉換成xxxSendMessage 消息物件
    append 到先前的空白array
    """
    # 解析json
    returnArray = []
    for jsonObject in jsonArray:

        # 讀取其用來判斷的元件
        message_type = jsonObject.get('type')
        
        # 轉換
        if message_type == 'text':
            returnArray.append(TextSendMessage.new_from_json_dict(jsonObject))
        elif message_type == 'imagemap':
            returnArray.append(ImagemapSendMessage.new_from_json_dict(jsonObject))
        elif message_type == 'template':
            returnArray.append(TemplateSendMessage.new_from_json_dict(jsonObject))
        elif message_type == 'image':
            returnArray.append(ImageSendMessage.new_from_json_dict(jsonObject))
        elif message_type == 'sticker':
            returnArray.append(StickerSendMessage.new_from_json_dict(jsonObject))  
        elif message_type == 'audio':
            returnArray.append(AudioSendMessage.new_from_json_dict(jsonObject))  
        elif message_type == 'location':
            returnArray.append(LocationSendMessage.new_from_json_dict(jsonObject))
        elif message_type == 'flex':
            returnArray.append(FlexSendMessage.new_from_json_dict(jsonObject))  
        elif message_type == 'video':
            returnArray.append(VideoSendMessage.new_from_json_dict(jsonObject))    


    # 回傳
    return returnArray

# %%
# 引用套件
from linebot.models import (
    MessageEvent, TextMessage
)


# 文字消息處理
@handler.add(MessageEvent,message=TextMessage)
def process_text_message(event):

    # 讀取本地檔案，並轉譯成消息
    result_message_array =[]
    # 用戶輸入文字 我就在本地方找相應的json
    replyJsonPath = "/content/drive/MyDrive/line_bot_content/" + event.message.text + ".json"
    result_message_array = detect_json_array_to_new_message_array(replyJsonPath)

    # 發送
    line_bot_api.reply_message(
        event.reply_token,
        result_message_array
    )

# %%
# 主程序運行
app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://3e5d-35-245-62-166.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 39, in detect_json_array_to_new_message_array
#     message_type = jsonObject.get('type')
# AttributeError: 'str' object has no attribute 'get'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:44:18] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 18, in process_text_message
#     line_bot_api.reply_message(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 116, in reply_message
#     self._post(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2033, in _post
#     self.__check_error(response)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2069, in __check_error
#     raise LineBotApiError(
# linebot.exceptions.LineBotApiError: LineBotApiError: status_code=400, request_id=e4c85f4c-7b24-4796-b705-b015c41332b9, error_response={"details": [{"message": "Invalid action URI"}], "message": "A message (messages[0])\u00a0in the request body is invalid"}, headers={'Content-Type': 'application/json', 'Server': 'envoy', 'x-content-type-options': 'nosniff', 'x-frame-options': 'DENY', 'x-line-request-id': 'e4c85f4c-7b24-4796-b705-b015c41332b9', 'x-xss-protection': '1; mode=block', 'Content-Length': '114', 'Expires': 'Thu, 16 Mar 2023 07:44:58 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Thu, 16 Mar 2023 07:44:58 GMT', 'Connection': 'close'}
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:44:58] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 18, in process_text_message
#     line_bot_api.reply_message(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 116, in reply_message
#     self._post(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2033, in _post
#     self.__check_error(response)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2069, in __check_error
#     raise LineBotApiError(
# linebot.exceptions.LineBotApiError: LineBotApiError: status_code=400, request_id=c1e6e61c-9b32-4d66-ba41-d995e02d2c2c, error_response={"details": [{"message": "Invalid action URI"}], "message": "A message (messages[0])\u00a0in the request body is invalid"}, headers={'Content-Type': 'application/json', 'Server': 'envoy', 'x-content-type-options': 'nosniff', 'x-frame-options': 'DENY', 'x-line-request-id': 'c1e6e61c-9b32-4d66-ba41-d995e02d2c2c', 'x-xss-protection': '1; mode=block', 'Content-Length': '114', 'Expires': 'Thu, 16 Mar 2023 07:45:33 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Thu, 16 Mar 2023 07:45:33 GMT', 'Connection': 'close'}
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:45:33] "POST / HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:46:43] "POST / HTTP/1.1" 200 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 18, in process_text_message
#     line_bot_api.reply_message(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 116, in reply_message
#     self._post(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2033, in _post
#     self.__check_error(response)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2069, in __check_error
#     raise LineBotApiError(
# linebot.exceptions.LineBotApiError: LineBotApiError: status_code=400, request_id=63988364-ef22-4e18-93e9-b992ea587ff3, error_response={"details": [{"message": "Must be a valid HTTPS URL", "property": "messages[1].originalContentUrl"}], "message": "The request body has 1 error(s)"}, headers={'Content-Type': 'application/json', 'Server': 'envoy', 'x-content-type-options': 'nosniff', 'x-frame-options': 'DENY', 'x-line-request-id': '63988364-ef22-4e18-93e9-b992ea587ff3', 'x-xss-protection': '1; mode=block', 'Content-Length': '141', 'Expires': 'Thu, 16 Mar 2023 07:47:26 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Thu, 16 Mar 2023 07:47:26 GMT', 'Connection': 'close'}
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:47:26] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 18, in process_text_message
#     line_bot_api.reply_message(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 116, in reply_message
#     self._post(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2033, in _post
#     self.__check_error(response)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2069, in __check_error
#     raise LineBotApiError(
# linebot.exceptions.LineBotApiError: LineBotApiError: status_code=400, request_id=adb646a4-7e30-449a-ab03-90d35657a2de, error_response={"details": [{"message": "Must be a valid HTTPS URL", "property": "messages[0].originalContentUrl"}], "message": "The request body has 1 error(s)"}, headers={'Content-Type': 'application/json', 'Server': 'envoy', 'x-content-type-options': 'nosniff', 'x-frame-options': 'DENY', 'x-line-request-id': 'adb646a4-7e30-449a-ab03-90d35657a2de', 'x-xss-protection': '1; mode=block', 'Content-Length': '141', 'Expires': 'Thu, 16 Mar 2023 07:47:43 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Thu, 16 Mar 2023 07:47:43 GMT', 'Connection': 'close'}
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:47:43] "POST / HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:47:58] "POST / HTTP/1.1" 200 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 27, in detect_json_array_to_new_message_array
#     jsonArray = json.load(f)
#   File "/usr/lib/python3.9/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.9/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.9/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.9/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 7 column 1 (char 332)
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:48:48] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 27, in detect_json_array_to_new_message_array
#     jsonArray = json.load(f)
#   File "/usr/lib/python3.9/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.9/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.9/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.9/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 7 column 1 (char 332)
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:49:20] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 27, in detect_json_array_to_new_message_array
#     jsonArray = json.load(f)
#   File "/usr/lib/python3.9/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.9/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.9/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.9/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 7 column 1 (char 332)
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:49:31] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 27, in detect_json_array_to_new_message_array
#     jsonArray = json.load(f)
#   File "/usr/lib/python3.9/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.9/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.9/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.9/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 4 column 25 (char 47)
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:51:05] "POST / HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:51:50] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:52:25] "POST / HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:53:16] "POST / HTTP/1.1" 200 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找弱小外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:53:30] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 27, in detect_json_array_to_new_message_array
#     jsonArray = json.load(f)
#   File "/usr/lib/python3.9/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.9/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.9/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.9/json/decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting ',' delimiter: line 67 column 1 (char 1779)
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:54:04] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找弱小外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:54:08] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 27, in detect_json_array_to_new_message_array
#     jsonArray = json.load(f)
#   File "/usr/lib/python3.9/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.9/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.9/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.9/json/decoder.py", line 355, in raw_decode
#     raise JSONDecodeError("Expecting value", s, err.value) from None
# json.decoder.JSONDecodeError: Expecting value: line 45 column 1 (char 1155)
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:54:21] "POST / HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:54:30] "POST / HTTP/1.1" 200 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 27, in detect_json_array_to_new_message_array
#     jsonArray = json.load(f)
#   File "/usr/lib/python3.9/json/__init__.py", line 293, in load
#     return loads(fp.read(),
#   File "/usr/lib/python3.9/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/usr/lib/python3.9/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/usr/lib/python3.9/json/decoder.py", line 353, in raw_decode
#     obj, end = self.scan_once(s, idx)
# json.decoder.JSONDecodeError: Expecting ',' delimiter: line 68 column 1 (char 1780)
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 07:54:55] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找弱小外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:00:45] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找強壯外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:00:46] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找暴力外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:00:47] "POST / HTTP/1.1" 500 -
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:02:32] "POST / HTTP/1.1" 200 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找弱小外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:02:47] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找強壯外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:02:48] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找暴力外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:02:49] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 18, in process_text_message
#     line_bot_api.reply_message(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 116, in reply_message
#     self._post(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2033, in _post
#     self.__check_error(response)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2069, in __check_error
#     raise LineBotApiError(
# linebot.exceptions.LineBotApiError: LineBotApiError: status_code=400, request_id=7b0f951f-3d5d-4c04-9d82-353bd2ec9bea, error_response={"details": [{"message": "Invalid action URI"}], "message": "A message (messages[0])\u00a0in the request body is invalid"}, headers={'Content-Type': 'application/json', 'Server': 'envoy', 'x-content-type-options': 'nosniff', 'x-frame-options': 'DENY', 'x-line-request-id': '7b0f951f-3d5d-4c04-9d82-353bd2ec9bea', 'x-xss-protection': '1; mode=block', 'Content-Length': '114', 'Expires': 'Thu, 16 Mar 2023 08:05:42 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Thu, 16 Mar 2023 08:05:42 GMT', 'Connection': 'close'}
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:05:42] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 18, in process_text_message
#     line_bot_api.reply_message(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 116, in reply_message
#     self._post(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2033, in _post
#     self.__check_error(response)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2069, in __check_error
#     raise LineBotApiError(
# linebot.exceptions.LineBotApiError: LineBotApiError: status_code=400, request_id=3b29ad01-8344-4fcd-9c60-31e21d8fbb19, error_response={"details": [{"message": "Invalid action URI"}], "message": "A message (messages[0])\u00a0in the request body is invalid"}, headers={'Content-Type': 'application/json', 'Server': 'envoy', 'x-content-type-options': 'nosniff', 'x-frame-options': 'DENY', 'x-line-request-id': '3b29ad01-8344-4fcd-9c60-31e21d8fbb19', 'x-xss-protection': '1; mode=block', 'Content-Length': '114', 'Expires': 'Thu, 16 Mar 2023 08:05:48 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Thu, 16 Mar 2023 08:05:48 GMT', 'Connection': 'close'}
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:05:48] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 18, in process_text_message
#     line_bot_api.reply_message(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 116, in reply_message
#     self._post(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2033, in _post
#     self.__check_error(response)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2069, in __check_error
#     raise LineBotApiError(
# linebot.exceptions.LineBotApiError: LineBotApiError: status_code=400, request_id=4d59a166-e481-45ee-a221-73b3b1ee05a4, error_response={"details": [{"message": "Invalid action URI"}], "message": "A message (messages[0])\u00a0in the request body is invalid"}, headers={'Content-Type': 'application/json', 'Server': 'envoy', 'x-content-type-options': 'nosniff', 'x-frame-options': 'DENY', 'x-line-request-id': '4d59a166-e481-45ee-a221-73b3b1ee05a4', 'x-xss-protection': '1; mode=block', 'Content-Length': '114', 'Expires': 'Thu, 16 Mar 2023 08:14:32 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Thu, 16 Mar 2023 08:14:32 GMT', 'Connection': 'close'}
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:14:32] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 39, in detect_json_array_to_new_message_array
#     message_type = jsonObject.get('type')
# AttributeError: 'str' object has no attribute 'get'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:14:54] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 39, in detect_json_array_to_new_message_array
#     message_type = jsonObject.get('type')
# AttributeError: 'str' object has no attribute 'get'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:14:57] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 18, in process_text_message
#     line_bot_api.reply_message(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 116, in reply_message
#     self._post(
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2033, in _post
#     self.__check_error(response)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/api.py", line 2069, in __check_error
#     raise LineBotApiError(
# linebot.exceptions.LineBotApiError: LineBotApiError: status_code=400, request_id=8e90feaa-83b8-4d4e-ae7c-bf9ed305c970, error_response={"details": [{"message": "Invalid action URI"}], "message": "A message (messages[0])\u00a0in the request body is invalid"}, headers={'Content-Type': 'application/json', 'Server': 'envoy', 'x-content-type-options': 'nosniff', 'x-frame-options': 'DENY', 'x-line-request-id': '8e90feaa-83b8-4d4e-ae7c-bf9ed305c970', 'x-xss-protection': '1; mode=block', 'Content-Length': '114', 'Expires': 'Thu, 16 Mar 2023 08:15:15 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Thu, 16 Mar 2023 08:15:15 GMT', 'Connection': 'close'}
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:15:15] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找強壯外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:15:16] "POST / HTTP/1.1" 500 -
# ERROR:__main__:Exception on / [POST]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 2528, in wsgi_app
#     response = self.full_dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1825, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1823, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "/usr/local/lib/python3.9/dist-packages/flask/app.py", line 1799, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#   File "<ipython-input-5-4651184fc34d>", line 13, in callback
#     handler.handle(body, signature)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 263, in handle
#     self.__invoke_func(func, event, payload)
#   File "/usr/local/lib/python3.9/dist-packages/linebot/webhook.py", line 275, in __invoke_func
#     func(event)
#   File "<ipython-input-11-15c096b7d6ad>", line 15, in process_text_message
#     result_message_array = detect_json_array_to_new_message_array(replyJsonPath)
#   File "<ipython-input-10-4f93eb169662>", line 26, in detect_json_array_to_new_message_array
#     with open(fileName,encoding='utf8') as f:
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/line_bot_content/我要找暴力外星人.json'
# INFO:werkzeug:127.0.0.1 - - [16/Mar/2023 08:15:18] "POST / HTTP/1.1" 500 -
