# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !unzip /content/drive/MyDrive/classifier_training_colab.zip
# Out:
# Archive:  /content/drive/MyDrive/classifier_training_colab.zip
#   inflating: classifier_training_colab/Data/Image.jpg
#    creating: classifier_training_colab/NEG/
#   inflating: classifier_training_colab/NEG/00000.png
#   inflating: classifier_training_colab/NEG/00001.png
#   inflating: classifier_training_colab/NEG/00002.png
#   inflating: classifier_training_colab/NEG/00003.png
#   inflating: classifier_training_colab/NEG/00004.png
#   inflating: classifier_training_colab/NEG/00005.png
#   inflating: classifier_training_colab/NEG/00006.png
#   inflating: classifier_training_colab/NEG/00007.png
#   inflating: classifier_training_colab/NEG/00008.png
#   inflating: classifier_training_colab/NEG/00009.png
#   inflating: classifier_training_colab/NEG/00010.png
#   inflating: classifier_training_colab/NEG/00011.png
#   inflating: classifier_training_colab/NEG/00012.png
#   inflating: classifier_training_colab/NEG/00013.png
#   inflating: classifier_training_colab/NEG/00014.png
# ...

# %%
# !python /content/drive/MyDrive/classifier_training_colab/training.py
# Out:
# POS/17.png
# POS/19.png
# POS/15.png
# POS/16.png
# POS/18.png
# POS/20.png
# POS/07.png
# POS/05.png
# POS/04.png
# POS/03.png
# POS/14.png
# POS/13.png
# POS/10.png
# POS/08.png
# POS/09.png
# POS/12.png
# POS/11.png
# POS/02.png
# POS/.ipynb_checkpoints
# NEG/00003.png
# NEG/00008.png
# NEG/00002.png
# NEG/img_0_821.jpg
# NEG/img_0_774.jpg
# NEG/img_0_803.jpg
# NEG/img_0_822.jpg
# NEG/00000.png
# NEG/img_0_801.jpg
# NEG/img_0_807.jpg
# NEG/img_0_831.jpg
# NEG/img_0_766.jpg
# NEG/img_0_757.jpg
# NEG/img_0_756.jpg
# NEG/img_0_827.jpg
# NEG/img_0_750.jpg
# NEG/img_0_605.jpg
# NEG/img_0_695.jpg
# NEG/img_0_631.jpg
# NEG/img_0_606.jpg
# NEG/img_0_622.jpg
# NEG/img_0_602.jpg
# NEG/img_0_666.jpg
# NEG/img_0_629.jpg
# NEG/img_0_726.jpg
# NEG/img_0_706.jpg
# NEG/img_0_599.jpg
# NEG/img_0_591.jpg
# NEG/img_0_512.jpg
# NEG/img_0_504.jpg
# NEG/img_0_431.jpg
# NEG/img_0_552.jpg
# NEG/img_0_528.jpg
# NEG/img_0_432.jpg
# NEG/img_0_569.jpg
# NEG/img_0_440.jpg
# NEG/img_0_570.jpg
# ...
