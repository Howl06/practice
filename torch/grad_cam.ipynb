# %% [markdown]
# <a href="https://colab.research.google.com/github/Howl06/practice/blob/main/grad_cam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python /content/drive/MyDrive/團專圖片/測試/predict_colab.py
import matplotlib.pyplot as plt
from PIL import Image

with open("/content/drive/MyDrive/團專圖片/測試/測試圖片路徑.txt", "r", encoding="utf-8") as f:
      file_img_path = f.read()
img_path = file_img_path
img = Image.open(img_path)
plt.imshow(img)
plt.axis("off")
plt.show()
# Out:
# class: fiona                    prob: 0.0287
# class: 十二之卷                     prob: 0.000629
# class: 千佛手                      prob: 0.00107
# class: 千兔耳                      prob: 0.00097
# class: 墨西哥雪球                    prob: 0.252
# class: 姬攏月                      prob: 0.0371
# class: 實生百合                     prob: 0.000717
# class: 月兔耳                      prob: 0.00461
# class: 桃蛋                       prob: 0.415
# class: 沙漠玫瑰                     prob: 0.00187
# class: 火祭                       prob: 0.000464
# class: 熊童子                      prob: 0.00224
# class: 白牡丹                      prob: 0.00248
# class: 石蓮                       prob: 0.00842
# class: 萬聖節法師                    prob: 0.000431
# class: 觀音蓮                      prob: 0.000621
# class: 達摩福娘                     prob: 0.013
# class: 錦司晃                      prob: 0.000918
# class: 雅樂之舞                     prob: 0.18
# class: 雪兔-麗娜蓮                   prob: 0.00111
# ...

# %%
# !python /content/drive/MyDrive/團專圖片/grad_cam/main_cnn.py

# %%
import matplotlib.pyplot as plt
from PIL import Image

img_path = "/content/drive/MyDrive/團專圖片/grad_cam/result.jpg"
img = Image.open(img_path)
plt.imshow(img)
plt.axis("off")
plt.show()
