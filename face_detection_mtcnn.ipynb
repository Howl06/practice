# %% [markdown]
# <a href="https://colab.research.google.com/github/Howl06/practice/blob/main/face_detection_mtcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mtcnn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mtcnn
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from mtcnn) (4.7.0.72)
# Requirement already satisfied: keras>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from mtcnn) (2.12.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from opencv-python>=4.1.0->mtcnn) (1.22.4)
# Installing collected packages: mtcnn
# Successfully installed mtcnn-0.1.1

# %%
# Download and unzip dataset
# !pip install --upgrade gdown
# !gdown --fuzzy 1RJ6MEDV9tYexOTAQDiWZ2bx8fO4HuUAu
# !unzip -q "5celeb.zip"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (4.6.6)
# Collecting gdown
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.12.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.11.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# Successfully installed gdown-4.7.1
# Downloading...
# From: https://drive.google.com/uc?id=1RJ6MEDV9tYexOTAQDiWZ2bx8fO4HuUAu
# To: /content/5celeb.zip
# 100% 2.73M/2.73M [00:00<00:00, 155MB/s]

# %%
import mtcnn
from mtcnn import MTCNN

import cv2
import matplotlib.pyplot as plt
import numpy as np
from glob import glob
from pprint import pprint

# %%
path = './5celeb/data/*/*/*.jpg'

# %%
# list pic_path
img_paths = glob(path)
print(len(glob(path)))
img_paths
# Out:
# 137
# ['./5celeb/data/val/madonna/httpassetsrollingstonecomassetsarticlemadonnadavidbowiechangedthecourseofmylifeforeversmallsquarexmadonnabowiejpg.jpg',
#  './5celeb/data/val/madonna/httpassetsrollingstonecomassetsimagesalbumreviewaffaceabdcccaeedjpg.jpg',
#  './5celeb/data/val/madonna/httpecximagesamazoncomimagesIfmaBKWLACULSRjpg.jpg',
#  './5celeb/data/val/madonna/httpcdncdnjustjaredcomwpcontentuploadsheadlinesmadonnatalksparisattackstearsjpg.jpg',
#  './5celeb/data/val/madonna/httpcdnfuncheapcomwpcontentuploadsVOGUEjpg.jpg',
#  './5celeb/data/val/elton_john/httpcdncdnjustjaredcomwpcontentuploadsheadlineseltonjohnstillstandingbrooklynnewyearsjpg.jpg',
#  './5celeb/data/val/elton_john/httpcdnlyricssongonlyricsnetwpcontentuploadsEltonJohnDiscographyCDreleasesjpg.jpg',
#  './5celeb/data/val/elton_john/httpcdncdnjustjaredcomwpcontentuploadsheadlineseltonjohnsupportsbrucejennerstransitiontowomanjpg.jpg',
#  './5celeb/data/val/elton_john/httpcdncdnjustjaredcomwpcontentuploadsheadlineseltonjohnemmysperformancewatchnowjpg.jpg',
#  './5celeb/data/val/elton_john/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTEODAOTcxNjcMjczMjkzjpg.jpg',
#  './5celeb/data/val/mindy_kaling/httpcdncdnjustjaredcomwpcontentuploadsheadlinesmindykalingcomedypilotjpg.jpg',
#  './5celeb/data/val/mindy_kaling/httpdbrbzkkbdsdcloudfrontnetwpcontentuploadsMindyKalingjpg.jpg',
#  './5celeb/data/val/mindy_kaling/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTIOTcwODQNTUzNjQMzcjpg.jpg',
#  './5celeb/data/val/mindy_kaling/httpcdnpastemagazinecomwwwarticlesmindyprojectjpg.jpg',
#  './5celeb/data/val/mindy_kaling/httpcdnpastemagazinecomwwwarticlesmindykalingndbookjpg.jpg',
#  './5celeb/data/val/jerry_seinfeld/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTIwNjANjMMDINzIxNjcjpg.jpg',
#  './5celeb/data/val/jerry_seinfeld/httpcdncdnjustjaredcomwpcontentuploadsheadlinesjerryseinfeldmakesbrianwilliamsjokejpg.jpg',
#  './5celeb/data/val/jerry_seinfeld/httpaurorasblogcomwpcontentuploadsjerryseinfeldpublicityshotjpg.jpg',
#  './5celeb/data/val/jerry_seinfeld/httpcdnssninsidercomwpcontentuploadsjerryseinfeldxjpg.jpg',
#  './5celeb/data/val/jerry_seinfeld/httpblognjcomentertainmentimpactcelebritiesmediumjerrybjpg.jpg',
#  './5celeb/data/val/ben_afflek/httpbpblogspotcomedLMjVpRGkSWexgsXjkNIAAAAAAAADWgFFtAUqBlhAsjpg.jpg',
#  './5celeb/data/val/ben_afflek/httpabsolumentgratuitfreefrimagesbenaffleckjpg.jpg',
#  './5celeb/data/val/ben_afflek/httpcsvkmeuaafdfjpg.jpg',
#  './5celeb/data/val/ben_afflek/httpcsvkmeuadecafjpg.jpg',
#  './5celeb/data/val/ben_afflek/httpafilesbiographycomimageuploadcfillcssrgbdprgfacehqwMTENDgMDUODczNDcNTcjpg.jpg',
#  './5celeb/data/val/張鈞甯/張鈞甯04.jpg',
#  './5celeb/data/val/張鈞甯/下載-4-1569381342.jpg',
#  './5celeb/data/val/張鈞甯/images.jpg',
#  './5celeb/data/val/張鈞甯/ffd5139a075191769b0710de2ef7b0af.jpg',
#  './5celeb/data/val/張鈞甯/md-6895d8a3af1b76267612914ff1c93375.jpg',
#  './5celeb/data/train/madonna/httpiamediaimdbcomimagesMMVBMTANDQNTAxNDVeQTJeQWpwZBbWUMDIMjQOTYVUXCRALjpg.jpg',
#  './5celeb/data/train/madonna/httpssmediacacheakpinimgcomxffabffabbbcfbceaedjpg.jpg',
#  './5celeb/data/train/madonna/httpresizeparismatchladmediafrrffffffcentermiddleimgvarnewsstorageimagesparismatchpeopleazmadonnafreFRMadonnajpg.jpg',
#  './5celeb/data/train/madonna/httpssmediacacheakpinimgcomxaaeaaeecccaedfebdbjpg.jpg',
#  './5celeb/data/train/madonna/httpssmediacacheakpinimgcomxfeebfdccajpg.jpg',
#  './5celeb/data/train/madonna/httpssmediacacheakpinimgcomxdcfdcfedfaedadjpg.jpg',
#  './5celeb/data/train/madonna/httpimgclosermagfrvarclosermagstorageimagesactupeoplebiodestarsmadonnamadonnafreFRmadonnaexactxljpg.jpg',
#  './5celeb/data/train/madonna/httpssmediacacheakpinimgcomxafafedebcbjpg.jpg',
#  './5celeb/data/train/madonna/httpwwwbeastiemaniacomwhoismadonnamadonnajpg.jpg',
#  './5celeb/data/train/madonna/httpssvagalumecommadonnaimagesmadonnajpg.jpg',
#  './5celeb/data/train/madonna/httpssmediacacheakpinimgcomxffecfafddjpg.jpg',
#  './5celeb/data/train/madonna/httpsuploadwikimediaorgwikipediacommonsMadonnathAnnualGoldenGlobesAwardscroppedjpg.jpg',
#  './5celeb/data/train/madonna/httpwwwblackdogfilmscomwordpresswpcontentuploadsmadonnacelebrationxjpg.jpg',
#  './5celeb/data/train/madonna/httpmediavoguecomrwblondesdarkbrowsmadonnajpg.jpg',
#  './5celeb/data/train/madonna/httpsuploadwikimediaorgwikipediacommonsthumbaaMadonnaatthepremiereofIAmBecauseWeArejpgpxMadonnaatthepremiereofIAmBecauseWeArejpg.jpg',
#  './5celeb/data/train/madonna/httpssmediacacheakpinimgcomxffeabacaaejpg.jpg',
#  './5celeb/data/train/madonna/httpuploadwikimediaorgwikipediacommonsthumbaMadonnaRotterdamjpgpxMadonnaRotterdamjpg.jpg',
#  './5celeb/data/train/madonna/httpwwwetonlinecomphotomadonnabdayjpg.jpg',
#  './5celeb/data/train/madonna/httpimagegaladevcmseamadonnaprivatdetektivsquaretopsquarejpgv.jpg',
#  './5celeb/data/train/elton_john/httpimagesmtvcomurimgidfiledocrootvhcomsitewideflipbooksimgdailyjpgenlargefalsemattetruematteColorblackquality.jpg',
#  './5celeb/data/train/elton_john/httpmediacacheecpinimgcomxffeffbcefjpg.jpg',
#  './5celeb/data/train/elton_john/httpmediapopsugarassetscomfilescbffewltonjpg.jpg',
#  './5celeb/data/train/elton_john/httpsdfrpwlycscloudfrontnetdeltonjohnjpg.jpg',
#  './5celeb/data/train/elton_john/httpwwweonlinecomresizewwweonlinecomeolimagesEntireSitersxEltonJohnJRjpg.jpg',
#  './5celeb/data/train/elton_john/httpspmctvlinefileswordpresscomeltonjohnjpg.jpg',
#  './5celeb/data/train/elton_john/httpssmediacacheakpinimgcomxfefdacfbfdeadajpg.jpg',
#  './5celeb/data/train/elton_john/httpwwwjohnpauljonesarenacomeventimagesEltonCalendarVjpg.jpg',
#  './5celeb/data/train/elton_john/httpsticketmnettmenusdamabbacdaebeafdbbCUSTOMjpg.jpg',
#  './5celeb/data/train/elton_john/httpftqncomymusicLxZeltonjohnjpg.jpg',
#  './5celeb/data/train/elton_john/httpiamediaimdbcomimagesMMVBMTAxNDUMzUwOTdeQTJeQWpwZBbWUMDUOTAyNTIVUXCRALjpg.jpg',
#  './5celeb/data/train/elton_john/httpssmediacacheakpinimgcomxfecfecaefaadfebejpg.jpg',
#  './5celeb/data/train/elton_john/httpwwwlautdeEltonJohneltonjohnjpg.jpg',
#  './5celeb/data/train/elton_john/httpsuploadwikimediaorgwikipediacommonsthumbEltonJohninsjpgpxEltonJohninsjpg.jpg',
#  './5celeb/data/train/elton_john/httpimggalpmdstaticnetfithttpAFFwwwEgalaEfrFvarFgalFstorageFimagesFmediaFmultiuploaddufevrierFeltonjohnFfreFRFeltonjohnEjpgxqualityeltonjohnjpg.jpg',
#  './5celeb/data/train/elton_john/httpssmediacacheakpinimgcomxfcfcbaeaeddabbjpg.jpg',
#  './5celeb/data/train/elton_john/httpwwwdeadlinecomvimgnetwpcontentuploadseltonjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpgraphicsnytimescomimagesmagazinekalingkalingarticleInlinejpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpwwwimpropercomimagesuploadsusercontentimagesSoroffMindyjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpimagesnymagcomimagesdailymindykalingxjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpssmediacacheakpinimgcomxccccdabeaadjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpsuploadwikimediaorgwikipediacommonsthumbMindyBKalingBPaleyFestBNewBYorkBBMindyBIqZgUWvbljpgpxMindyBKalingBPaleyFestBNewBYorkBBMindyBIqZgUWvbljpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpwwwadweekcomfilesimagecachenodeinlinemindykalingprofilehedjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpwwwbooksforbetterlivingcomwpcontentuploadsMindyKalingAuthorPhotojpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpssmediacacheakpinimgcomxbabafeacbaaacabffjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpmediaonsugarcomfilesbabaaaaaMindyInterviewxxxlargejpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpsimagesnasslimagesamazoncomimagesIAQdwKvFILUXjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpsimgbuzzfeedcombuzzfeedstaticstaticcampaignimageswebdradorableetsyitemsallmindykalingfansneedbigjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpssmediacacheakpinimgcomxededbebccdajpg.jpg',
#  './5celeb/data/train/mindy_kaling/httppixelnymagcomimgsfashiondailymindykalingwhjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpgonetworthcomwpcontentuploadsthumbsjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpssmediacacheakpinimgcomxafaffbbbbdbcbdddjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpssmediacacheakpinimgcomxcccccddbbfedabjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpsamazonawscomkidzworldphotoimagesbccdddaaadgallerymindykalinggalleryjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpwwwpictureszimbiocomgiMindyKalingLkvEhTwDeJmjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpwwwpictureszimbiocomfpMindyKalingfBgaONVFDFmjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpssmediacacheakpinimgcomxeedccadejpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpwwweonlinecomeolimagesEntireSiteregKalingCancermhjpg.jpg',
#  './5celeb/data/train/mindy_kaling/httpssmediacacheakpinimgcomxbbfcbdedfbfdbjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpwwwwatchidcomsitesdefaultfilesuploadsightingBreitlingwatchJerrySeinfeldjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpsuswestamazonawscomblogsprodmediausuploadsJerrySeinfeldkidsxjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpsuploadwikimediaorgwikipediacommonsthumbbJerrySeinfeldjpgpxJerrySeinfeldjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpwwwslatecomcontentdamslateblogsbrowbeatseinfeldjpgCROParticlemediumjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpimagescontactmusiccomnewsimagesjerryseinfeldjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpgraphicsnytimescomimagessectionmoviesfilmographyWireImagejpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpsrobertaccetturacomwpcontentuploadsjerryseinfeldheadshotjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpimgtimeincnetpeopleinewsjerryseinfeldjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpswwwticketscomuploadsartistsjerryseinfeldbilletsjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpstatictherichestimagescomcdncwpcontentuploadsJerrySeinfeldjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpimgthedrumcomsfspublicnewstmpjerryseinfeldjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpwwwpictureszimbiocomgpJerrySeinfeldJessicaSeinfeldmarriedBczSipMdNMQljpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpwwwpsychiatrictimescomsitesdefaultfilesimagesmediaPTMofficSeinfeldjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httppfodcompchannelslegacyprofilejerryseinfeldpodcastjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpsmedialivenationcomartiststapjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpsticketmnettmenusdbimagesajpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpimagesrottentomatoescomimagesspotlightsnewsjerryseinfeldjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpwwwnndbcompeoplejerryseinfeldaujpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpmediapopsugarassetscomfilesusersxlargejpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpwwweonlinecomresizewwweonlinecomeolimagesEntireSitersxjerryseinfeldjulialouisdreyfusjwjpg.jpg',
#  './5celeb/data/train/jerry_seinfeld/httpikinjaimgcomgawkermediaimageuploadsWmIuhdsrcedidjpgjpg.jpg',
#  './5celeb/data/train/ben_afflek/httpimagesfandangocomrImageRendererredesignstaticimgnoxportraitjpgpcpcpcimagesmasterrepositoryperformerimagespjpg.jpg',
#  './5celeb/data/train/ben_afflek/httpssmediacacheakpinimgcomxeebdfdbaaajpg.jpg',
#  './5celeb/data/train/ben_afflek/httpssmediacacheakpinimgcomxedaedabcbefbcbabbjpg.jpg',
#  './5celeb/data/train/ben_afflek/httpssmediacacheakpinimgcomxdfdfadcfeabjpg.jpg',
#  './5celeb/data/train/ben_afflek/httptrwebimgacstanetcxbdddmediasnmediajpg.jpg',
#  './5celeb/data/train/ben_afflek/httpwwwallposterscomimagesPostersPFjpg.jpg',
#  './5celeb/data/train/ben_afflek/httpwwwhillsindcomstorebenjpg.jpg',
#  './5celeb/data/train/ben_afflek/httpwwwfilmscoopitcgibinattoriBENAFFLECKBENAFFLECKjpg.jpg',
#  './5celeb/data/train/ben_afflek/httpssmediacacheakpinimgcomxeeedcacddeccccacfjpg.jpg',
#  './5celeb/data/train/ben_afflek/httpssmediacacheakpinimgcomxdbbdbbbececacdecdcdfjpg.jpg',
#  './5celeb/data/train/ben_afflek/httpsuploadwikimediaorgwikipediacommonsthumbddBenAffleckbyGageSkidmorejpgpxBenAffleckbyGageSkidmorejpg.jpg',
#  './5celeb/data/train/ben_afflek/httpwwwaceshowbizcomimagesphotobenaffleckjpg.jpg',
#  './5celeb/data/train/ben_afflek/httpwwwrumenewscomwpcontentuploadsbenafflekxpng.jpg',
#  './5celeb/data/train/ben_afflek/httpcsvkmeuaeccjpg.jpg',
#  './5celeb/data/train/張鈞甯/20230216001732.jpg',
#  './5celeb/data/train/張鈞甯/220415-19459-2-ArkJu.jpg',
#  './5celeb/data/train/張鈞甯/20191007181309-8e6be265229c26115831168470b888f0-mobile.jpg',
#  './5celeb/data/train/張鈞甯/2613645-PH.jpg',
#  './5celeb/data/train/張鈞甯/1768069-XXL.jpg',
#  './5celeb/data/train/張鈞甯/55.jpg',
#  './5celeb/data/train/張鈞甯/8ee97d95-c7db-4811-90ea-f9e52232a8ad.jpg',
#  './5celeb/data/train/張鈞甯/befunky-collage-3-1600356559.jpg',
#  './5celeb/data/train/張鈞甯/108681.jpg',
#  './5celeb/data/train/張鈞甯/20200117001449.jpg',
#  './5celeb/data/train/張鈞甯/11874021_980x1200_281.jpg',
#  './5celeb/data/train/張鈞甯/3  在全新曝光的2016秋冬女性運動服飾系列形象圖當中，元氣女神張鈞甯展示專屬運動女孩的秋冬運動時尚.jpg',
#  './5celeb/data/train/張鈞甯/3304736-PH.jpg',
#  './5celeb/data/train/張鈞甯/article-5f9011b2a2aac.jpg']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# create the detector, using default weights
detector = MTCNN()

# %%
# read image
img = cv2.imread(img_paths[135])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# detect face
results = detector.detect_faces(img)

pprint(results)
# Out:
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 24ms/step
# 3/3 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 37ms/step
# [{'box': [329, 56, 181, 277],
#   'confidence': 0.999979555606842,
#   'keypoints': {'left_eye': (371, 170),
#                 'mouth_left': (370, 256),
#                 'mouth_right': (462, 255),
#                 'nose': (413, 232),
#                 'right_eye': (456, 170)}}]

# %%
# extract the bounding box from the first face
x1, y1, width, height = results[0]['box']
x2, y2 = x1 + width, y1 + height
print((x1, y1), (x2, y2), img.shape)
plt.imshow(img)
# Out:
# (329, 56) (510, 333) (451, 800, 3)

# %%
for path in np.random.choice(img_paths[133:], 5):
    # read image
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # detect face
    results = detector.detect_faces(img)
    # extract the bounding box from the first face
    assert len(results) >= 1
    x1, y1, width, height = results[0]['box']
    x2, y2 = x1 + width, y1 + height

    print(x1, x2, y1, y2)
    # crop face
    patch = img[max(y1, 0):y2, max(x1, 0):x2].copy()
    # draw bbox
    img = cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 3)

    # show image
    plt.imshow(patch)
    plt.show()
    plt.imshow(img)
    plt.show()
# Out:
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 48ms/step
# 302 487 100 351
# 1/1 [==============================] - 1s 568ms/step
# 1/1 [==============================] - 0s 248ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 4/4 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 28ms/step
# 655 955 225 618
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 3/3 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 36ms/step
# 329 510 56 333
# 1/1 [==============================] - 0s 247ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 4/4 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 29ms/step
# 655 955 225 618
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 3/3 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 35ms/step
# 329 510 56 333
